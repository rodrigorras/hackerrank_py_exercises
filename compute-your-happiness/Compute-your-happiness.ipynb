# %% [markdown]
# ![image.png](attachment:52f76e6d-df05-4dc9-8825-8b88d741ccde.png)

# %% [markdown]
# ![image.png](attachment:4de0cc26-1f77-4a12-8fb4-f3511dbce778.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    n, m = map(int, input().split())

    # Read the array as a list of integers
    array = list(map(int, input().split()))

    # Read sets A and B
    A = set(map(int, input().split()))
    B = set(map(int, input().split()))

happiness = 0

for number in array:
    if number in A:
        happiness = happiness + 1

    if number in B:
        happiness = happiness - 1 
      
print(happiness)

# %% [markdown]
# <h3> With some Inputs </h3>

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__ == '__main__':
    # n, m = input().split()
    # array = input()
    # A = set(input().split())
    # B = set(input().split())

    n, m = 5, 5
    
    array = [999999991, 999999992, 999999993, 999999994,  999999999]
    A = {999999991, 999999993, 999999995, 999999999, 999999997}
    B = {999999990, 999999992, 999999996, 999999998, 999999994}

    # Initialize happiness
    happiness = 0

    # Calculate happiness
    for number in array:
        if number in A:
            happiness += 1
        if number in B:
            happiness -= 1

    # Print the result
    print(happiness)
# Out:
# 1
